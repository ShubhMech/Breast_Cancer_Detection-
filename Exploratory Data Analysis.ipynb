# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %%
bc=pd.read_csv(r"D:\Asus\Videos\breastCancer.csv")

# %% [markdown]
# # Exploratory Data Analysis

# %%
bc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 699 non-null    int64
#  1   clump_thickness    699 non-null    int64
#  2   size_uniformity    699 non-null    int64
#  3   shape_uniformity   699 non-null    int64
#  4   marginal_adhesion  699 non-null    int64
#  5   epithelial_size    699 non-null    int64
#  6   bare_nucleoli      699 non-null    object
#  7   bland_chromatin    699 non-null    int64
#  8   normal_nucleoli    699 non-null    int64
#  9   mitoses            699 non-null    int64
#  10  class              699 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 60.2+ KB

# %%
bc.describe().T
# Out:
#                    count          mean            std      min       25%  \
# id                 699.0  1.071704e+06  617095.729819  61634.0  870688.5
# clump_thickness    699.0  4.417740e+00       2.815741      1.0       2.0
# size_uniformity    699.0  3.134478e+00       3.051459      1.0       1.0
# shape_uniformity   699.0  3.207439e+00       2.971913      1.0       1.0
# marginal_adhesion  699.0  2.806867e+00       2.855379      1.0       1.0
# epithelial_size    699.0  3.216023e+00       2.214300      1.0       2.0
# bland_chromatin    699.0  3.437768e+00       2.438364      1.0       2.0
# normal_nucleoli    699.0  2.866953e+00       3.053634      1.0       1.0
# mitoses            699.0  1.589413e+00       1.715078      1.0       1.0
# class              699.0  2.689557e+00       0.951273      2.0       2.0
#
#                          50%        75%         max
# id                 1171710.0  1238298.0  13454352.0
# clump_thickness          4.0        6.0        10.0
# ...

# %%
bc.head(30)
# Out:
#          id  clump_thickness  size_uniformity  shape_uniformity  \
# 0   1000025                5                1                 1
# 1   1002945                5                4                 4
# 2   1015425                3                1                 1
# 3   1016277                6                8                 8
# 4   1017023                4                1                 1
# 5   1017122                8               10                10
# 6   1018099                1                1                 1
# 7   1018561                2                1                 2
# 8   1033078                2                1                 1
# 9   1033078                4                2                 1
# 10  1035283                1                1                 1
# 11  1036172                2                1                 1
# 12  1041801                5                3                 3
# 13  1043999                1                1                 1
# ...

# %%
bc.shape
# Out:
# (699, 11)

# %% [markdown]
# # Data PreProcessing

# %%
bc['class']=bc['class'].astype('category')

# %%
bc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 699 non-null    int64
#  1   clump_thickness    699 non-null    int64
#  2   size_uniformity    699 non-null    int64
#  3   shape_uniformity   699 non-null    int64
#  4   marginal_adhesion  699 non-null    int64
#  5   epithelial_size    699 non-null    int64
#  6   bare_nucleoli      699 non-null    object
#  7   bland_chromatin    699 non-null    int64
#  8   normal_nucleoli    699 non-null    int64
#  9   mitoses            699 non-null    int64
#  10  class              699 non-null    category
# dtypes: category(1), int64(9), object(1)
# memory usage: 55.5+ KB

# %%
bc['class'].value_counts()
# Out:
# 2    458
# 4    241
# Name: class, dtype: int64

# %% [markdown]
# ## 2= Benign and  4= Malignant

# %%
bc[bc['bare_nucleoli']== '?'].sum()
# Out:
# id                           13721250
# clump_thickness                    54
# size_uniformity                    39
# shape_uniformity                   46
# marginal_adhesion                  29
# epithelial_size                    39
# bare_nucleoli        ????????????????
# bland_chromatin                    50
# normal_nucleoli                    44
# mitoses                            16
# dtype: object

# %%
(bc['bare_nucleoli']== '?').sum()
# Out:
# 16

# %%
bc.replace('?',np.nan, inplace=True)

bc.head(30)
# Out:
#          id  clump_thickness  size_uniformity  shape_uniformity  \
# 0   1000025                5                1                 1
# 1   1002945                5                4                 4
# 2   1015425                3                1                 1
# 3   1016277                6                8                 8
# 4   1017023                4                1                 1
# 5   1017122                8               10                10
# 6   1018099                1                1                 1
# 7   1018561                2                1                 2
# 8   1033078                2                1                 1
# 9   1033078                4                2                 1
# 10  1035283                1                1                 1
# 11  1036172                2                1                 1
# 12  1041801                5                3                 3
# 13  1043999                1                1                 1
# ...

# %%
bc.fillna(bc.median(), inplace=True)

# %%
bc.dtypes
# Out:
# id                      int64
# clump_thickness         int64
# size_uniformity         int64
# shape_uniformity        int64
# marginal_adhesion       int64
# epithelial_size         int64
# bare_nucleoli          object
# bland_chromatin         int64
# normal_nucleoli         int64
# mitoses                 int64
# class                category
# dtype: object

# %%
bc['bare_nucleoli']=bc['bare_nucleoli'].astype('int64')

# %%
bc.dtypes
# Out:
# id                      int64
# clump_thickness         int64
# size_uniformity         int64
# shape_uniformity        int64
# marginal_adhesion       int64
# epithelial_size         int64
# bare_nucleoli           int64
# bland_chromatin         int64
# normal_nucleoli         int64
# mitoses                 int64
# class                category
# dtype: object

# %%
bc.drop('id', inplace=True, axis=1)

# %%
bc.head()
# Out:
#    clump_thickness  size_uniformity  shape_uniformity  marginal_adhesion  \
# 0                5                1                 1                  1
# 1                5                4                 4                  5
# 2                3                1                 1                  1
# 3                6                8                 8                  1
# 4                4                1                 1                  3
#
#    epithelial_size  bare_nucleoli  bland_chromatin  normal_nucleoli  mitoses  \
# 0                2              1                3                1        1
# 1                7             10                3                2        1
# 2                2              2                3                1        1
# 3                3              4                3                7        1
# 4                2              1                3                1        1
#
#   class
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2

# %%
bc.describe().T
# Out:
#                    count      mean       std  min  25%  50%  75%   max
# clump_thickness    699.0  4.417740  2.815741  1.0  2.0  4.0  6.0  10.0
# size_uniformity    699.0  3.134478  3.051459  1.0  1.0  1.0  5.0  10.0
# shape_uniformity   699.0  3.207439  2.971913  1.0  1.0  1.0  5.0  10.0
# marginal_adhesion  699.0  2.806867  2.855379  1.0  1.0  1.0  4.0  10.0
# epithelial_size    699.0  3.216023  2.214300  1.0  2.0  2.0  4.0  10.0
# bare_nucleoli      699.0  3.486409  3.621929  1.0  1.0  1.0  5.0  10.0
# bland_chromatin    699.0  3.437768  2.438364  1.0  2.0  3.0  5.0  10.0
# normal_nucleoli    699.0  2.866953  3.053634  1.0  1.0  1.0  4.0  10.0
# mitoses            699.0  1.589413  1.715078  1.0  1.0  1.0  1.0  10.0

# %%
bc.isna().sum()
# Out:
# clump_thickness      0
# size_uniformity      0
# shape_uniformity     0
# marginal_adhesion    0
# epithelial_size      0
# bare_nucleoli        0
# bland_chromatin      0
# normal_nucleoli      0
# mitoses              0
# class                0
# dtype: int64

# %% [markdown]
# # Uni-Variate Data Analysyis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(bc['clump_thickness'])
# Out:
# <AxesSubplot:xlabel='clump_thickness', ylabel='Density'>

# %%
sns.distplot(bc['size_uniformity'])
# Out:
# <AxesSubplot:xlabel='size_uniformity', ylabel='Density'>

# %%
sns.distplot(bc['shape_uniformity'])
# Out:
# <AxesSubplot:xlabel='shape_uniformity', ylabel='Density'>

# %%
sns.distplot(bc['marginal_adhesion'])
# Out:
# <AxesSubplot:xlabel='marginal_adhesion', ylabel='Density'>

# %%
sns.distplot(bc['epithelial_size'])
# Out:
# <AxesSubplot:xlabel='epithelial_size', ylabel='Density'>

# %%
sns.distplot(bc['bare_nucleoli'])
# Out:
# <AxesSubplot:xlabel='bare_nucleoli', ylabel='Density'>

# %% [markdown]
# # Bi-Variate Data Analysis

# %%
sns.scatterplot(bc['bare_nucleoli'],bc['epithelial_size'] )
# Out:
# <AxesSubplot:xlabel='bare_nucleoli', ylabel='epithelial_size'>

# %%
sns.scatterplot(bc['epithelial_size'],bc['marginal_adhesion'] )
# Out:
# <AxesSubplot:xlabel='epithelial_size', ylabel='marginal_adhesion'>

# %% [markdown]
# ## Multi-Variate Data Analysis

# %%
bc.hist(bins=40, figsize=[30,30], layout=(6,3));

# %%
bc.boxplot(figsize=[30,10])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=bc, orient='h')
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data=bc);

# %% [markdown]
# sns.hist(data=bc)

# %%
sns.heatmap(bc.corr(), annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=[30,30])
sns.pairplot(bc, diag_kind='kde')

# %%
x=bc.iloc[:,:-1] #Independent Variables

# %%
y=bc.iloc[:,-1] #Dependent Variable

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split as split

xtrain, xtest, ytrain, ytest=split(x,y, test_size=0.3)
